# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("ftp://aftp.cmdl.noaa.gov/products/trends/co2/co2_mm_mlo.txt", header=None, sep="\s+", comment="#")

# %%
df.columns=['year','month','decimal','average',"interpolated",'trend','days']

# %%
df_select=df[['year','month','average']]

# %%
df_select.columns=['year','month','CO2']

# %%
for i,row in df_select.iterrows():
    if row['CO2']==-99.99:
        df_select.loc[i,'CO2']=np.nan
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_select
# Out:
#      year  month     CO2  Day
# 0    1958      3  315.71   15
# 1    1958      4  317.45   15
# 2    1958      5  317.50   15
# 3    1958      6     NaN   15
# 4    1958      7  315.86   15
# 5    1958      8  314.93   15
# 6    1958      9  313.20   15
# 7    1958     10     NaN   15
# 8    1958     11  313.33   15
# 9    1958     12  314.67   15
# 10   1959      1  315.62   15
# 11   1959      2  316.38   15
# 12   1959      3  316.71   15
# 13   1959      4  317.72   15
# 14   1959      5  318.29   15
# 15   1959      6  318.15   15
# 16   1959      7  316.54   15
# 17   1959      8  314.80   15
# 18   1959      9  313.84   15
# 19   1959     10  313.26   15
# 20   1959     11  314.80   15
# 21   1959     12  315.58   15
# 22   1960      1  316.43   15
# 23   1960      2  316.97   15
# 24   1960      3  317.58   15
# 25   1960      4  319.02   15
# 26   1960      5  320.03   15
# 27   1960      6  319.59   15
# 28   1960      7  318.18   15
# 29   1960      8  315.91   15
# ...

# %%
df_select['Day']=15
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_select['Datetime']=pd.to_datetime(dict(year=df_select.year, month=df_select.month, day=df_select.Day))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_select.drop('Day',axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_select
# Out:
#      year  month     CO2   Datetime
# 0    1958      3  315.71 1958-03-15
# 1    1958      4  317.45 1958-04-15
# 2    1958      5  317.50 1958-05-15
# 3    1958      6     NaN 1958-06-15
# 4    1958      7  315.86 1958-07-15
# 5    1958      8  314.93 1958-08-15
# 6    1958      9  313.20 1958-09-15
# 7    1958     10     NaN 1958-10-15
# 8    1958     11  313.33 1958-11-15
# 9    1958     12  314.67 1958-12-15
# 10   1959      1  315.62 1959-01-15
# 11   1959      2  316.38 1959-02-15
# 12   1959      3  316.71 1959-03-15
# 13   1959      4  317.72 1959-04-15
# 14   1959      5  318.29 1959-05-15
# 15   1959      6  318.15 1959-06-15
# 16   1959      7  316.54 1959-07-15
# 17   1959      8  314.80 1959-08-15
# 18   1959      9  313.84 1959-09-15
# 19   1959     10  313.26 1959-10-15
# 20   1959     11  314.80 1959-11-15
# 21   1959     12  315.58 1959-12-15
# 22   1960      1  316.43 1960-01-15
# 23   1960      2  316.97 1960-02-15
# 24   1960      3  317.58 1960-03-15
# ...

# %%
a=[1,2,3]
b=a.pop()

# %%
b
# Out:
# 3

# %%
a
# Out:
# [1, 2]
